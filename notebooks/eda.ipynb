# %% [markdown]
# <h1>EDA to get buyer and seller valuation</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file into a DataFrame
df = pd.read_csv("../datasets/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
# print last row 
df.tail()
# Out:
#           month    town  flat_type block     street_name storey_range  \
# 175470  2024-03  YISHUN  EXECUTIVE   791    YISHUN AVE 2     10 TO 12
# 175471  2024-03  YISHUN  EXECUTIVE   392    YISHUN AVE 6     07 TO 09
# 175472  2024-03  YISHUN  EXECUTIVE   326  YISHUN RING RD     10 TO 12
# 175473  2024-03  YISHUN  EXECUTIVE   360  YISHUN RING RD     04 TO 06
# 175474  2024-03  YISHUN  EXECUTIVE   606    YISHUN ST 61     07 TO 09
#
#         floor_area_sqm  flat_model  lease_commence_date     remaining_lease  \
# 175470           146.0   Apartment                 1987  62 years 07 months
# 175471           146.0  Maisonette                 1988  63 years 04 months
# 175472           146.0  Maisonette                 1988  63 years 05 months
# 175473           146.0  Maisonette                 1988  63 years 05 months
# 175474           142.0   Apartment                 1987  62 years 10 months
#
#         resale_price
# 175470      851888.0
# 175471      830000.0
# 175472      820000.0
# 175473      860000.0
# 175474      780000.0
